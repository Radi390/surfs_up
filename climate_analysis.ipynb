# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite", echo=True)

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
# Out:
# 2022-04-23 20:07:20,987 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-04-23 20:07:20,990 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:20,991 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("measurement")
# 2022-04-23 20:07:20,993 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:20,993 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-04-23 20:07:20,994 INFO sqlalchemy.engine.Engine [raw sql] ('measurement',)
# 2022-04-23 20:07:20,995 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("measurement")
# 2022-04-23 20:07:20,995 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:20,996 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("measurement")
# 2022-04-23 20:07:20,996 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:20,997 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-04-23 20:07:20,997 INFO sqlalchemy.engine.Engine [raw sql] ('measurement',)
# 2022-04-23 20:07:20,998 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("measurement")
# 2022-04-23 20:07:20,999 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:20,999 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("measurement")
# 2022-04-23 20:07:20,999 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,000 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("measurement")
# 2022-04-23 20:07:21,001 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,002 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("measurement")
# 2022-04-23 20:07:21,002 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,003 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-04-23 20:07:21,003 INFO sqlalchemy.engine.Engine [raw sql] ('measurement',)
# 2022-04-23 20:07:21,005 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("station")
# 2022-04-23 20:07:21,006 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,008 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-04-23 20:07:21,008 INFO sqlalchemy.engine.Engine [raw sql] ('station',)
# 2022-04-23 20:07:21,009 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("station")
# 2022-04-23 20:07:21,009 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,011 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("station")
# 2022-04-23 20:07:21,011 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,013 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-04-23 20:07:21,013 INFO sqlalchemy.engine.Engine [raw sql] ('station',)
# 2022-04-23 20:07:21,014 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("station")
# 2022-04-23 20:07:21,014 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,015 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("station")
# 2022-04-23 20:07:21,015 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,016 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("station")
# 2022-04-23 20:07:21,016 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,016 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("station")
# 2022-04-23 20:07:21,016 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-23 20:07:21,018 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-04-23 20:07:21,018 INFO sqlalchemy.engine.Engine [raw sql] ('station',)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
#Starting from the last data point in the database. 
prev_year = dt.date(2017, 8, 23)
# Calculate the date one year from the last date in data set.
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)
# Perform a query to retrieve the data and precipitation scores
results = []
results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()
#print(results)
# Save the query results as a Pandas DataFrame and set the index to the date column
df = pd.DataFrame(results, columns=['date','precipitation'])
df.set_index(df['date'], inplace=True)


# Sort the dataframe by date
df = df.sort_index()
#print(df.to_string(index=False))
# Use Pandas Plotting with Matplotlib to plot the data
df.plot(figsize=(16,10))
# Out:
# 2022-04-23 20:12:17,942 INFO sqlalchemy.engine.Engine SELECT measurement.date AS measurement_date, measurement.prcp AS measurement_prcp
# FROM measurement
# WHERE measurement.date >= ?
# 2022-04-23 20:12:17,943 INFO sqlalchemy.engine.Engine [cached since 290.1s ago] ('2016-08-23',)
# <AxesSubplot:xlabel='date'>

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# How many stations are available in this dataset?
session.query(func.count(Station.station)).all()
# Out:
# 2021-12-25 19:40:44,678 INFO sqlalchemy.engine.Engine SELECT count(station.station) AS count_1
# FROM station
# 2021-12-25 19:40:44,679 INFO sqlalchemy.engine.Engine [generated in 0.00082s] ()
# [(9,)]

# %%
# What are the most active stations?
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).\
    group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# 2021-12-25 19:40:45,395 INFO sqlalchemy.engine.Engine SELECT measurement.station AS measurement_station, count(measurement.station) AS count_1
# FROM measurement GROUP BY measurement.station ORDER BY count(measurement.station) DESC
# 2021-12-25 19:40:45,396 INFO sqlalchemy.engine.Engine [generated in 0.00095s] ()
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?
session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
    filter(Measurement.station == 'USC00519281').all()
# Out:
# 2021-12-25 19:40:46,714 INFO sqlalchemy.engine.Engine SELECT min(measurement.tobs) AS min_1, max(measurement.tobs) AS max_1, avg(measurement.tobs) AS avg_1
# FROM measurement
# WHERE measurement.station = ?
# 2021-12-25 19:40:46,716 INFO sqlalchemy.engine.Engine [generated in 0.00096s] ('USC00519281',)
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
results = session.query(Measurement.tobs).\
    filter(Measurement.station == 'USC00519281').\
    filter(Measurement.date >= prev_year).all()
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
df = pd.DataFrame(results, columns=['tobs'])
df.plot.hist(bins=12)
plt.tight_layout()
# Out:
# 2021-12-25 19:40:48,061 INFO sqlalchemy.engine.Engine SELECT measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE measurement.station = ? AND measurement.date >= ?
# 2021-12-25 19:40:48,063 INFO sqlalchemy.engine.Engine [generated in 0.00131s] ('USC00519281', '2016-08-23')

# %%
# Write a function called `calc_temps` that will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates

# %% [markdown]
# # Challenge
